# %%
import yfinance as yf
import pandas as pd
import numpy as np
import statistics
import csv
from datetime import datetime, timedelta, date
import statistics
import mplfinance as mpf
import time
# import pandas as pd
import ta
import datetime
pd.set_option('display.max_rows', None)
pd.set_option('display.max_columns', None)
pd.set_option('display.width', None)

# %%
Starttime = "2023-06-12"
Endtime = "2023-07-11"
Interval = "15m"
today = date.today()

# %% [markdown]
# ## Sorting Companies

# %%
reader = pd.read_csv("Nifty_50_companies_list.csv")
column_list = reader['Symbol'].tolist()
modified_list = [item + '.NS' for item in column_list]
print(modified_list)

data = yf.download(modified_list, period='2d',interval='15m')['Close']
# Out:
# ['ADANIENT.NS', 'ADANIPORTS.NS', 'APOLLOHOSP.NS', 'ASIANPAINT.NS', 'AXISBANK.NS', 'BAJAJ-AUTO.NS', 'BAJFINANCE.NS', 'BAJAJFINSV.NS', 'BPCL.NS', 'BHARTIARTL.NS', 'BRITANNIA.NS', 'CIPLA.NS', 'COALINDIA.NS', 'DIVISLAB.NS', 'DRREDDY.NS', 'EICHERMOT.NS', 'GRASIM.NS', 'HCLTECH.NS', 'HDFCBANK.NS', 'HDFCLIFE.NS', 'HEROMOTOCO.NS', 'HINDALCO.NS', 'HINDUNILVR.NS', 'HDFC.NS', 'ICICIBANK.NS', 'ITC.NS', 'INDUSINDBK.NS', 'INFY.NS', 'JSWSTEEL.NS', 'KOTAKBANK.NS', 'LT.NS', 'M&M.NS', 'MARUTI.NS', 'NTPC.NS', 'NESTLEIND.NS', 'ONGC.NS', 'POWERGRID.NS', 'RELIANCE.NS', 'SBILIFE.NS', 'SBIN.NS', 'SUNPHARMA.NS', 'TCS.NS', 'TATACONSUM.NS', 'TATAMOTORS.NS', 'TATASTEEL.NS', 'TECHM.NS', 'TITAN.NS', 'UPL.NS', 'ULTRACEMCO.NS', 'WIPRO.NS']
# [*********************100%***********************]  50 of 50 completed
#
# 1 Failed download:
# - INFY.NS: No data found for this date range, symbol may be delisted

# %%
data.head()
# Out:
#                      ADANIENT.NS  ADANIPORTS.NS  APOLLOHOSP.NS  ASIANPAINT.NS  \
# 2023-07-11 09:15:00  2420.000000     728.150024    5245.850098    3366.949951
# 2023-07-11 09:30:00  2422.000000     730.799988    5257.850098    3385.500000
# 2023-07-11 09:45:00  2431.949951     730.000000    5260.000000    3388.000000
# 2023-07-11 10:00:00  2424.000000     728.650024    5246.649902    3374.500000
# 2023-07-11 10:15:00  2431.449951     731.000000    5227.000000    3375.000000
#
#                      AXISBANK.NS  BAJAJ-AUTO.NS  BAJAJFINSV.NS  BAJFINANCE.NS  \
# 2023-07-11 09:15:00   967.950012    4919.100098    1627.800049    7668.450195
# 2023-07-11 09:30:00   966.849976    4932.500000    1624.449951    7646.700195
# 2023-07-11 09:45:00   966.000000    4938.649902    1624.300049    7646.100098
# 2023-07-11 10:00:00   964.599976    4940.000000    1625.000000    7612.000000
# 2023-07-11 10:15:00   965.150024    4932.049805    1622.650024    7617.149902
#
#                      BHARTIARTL.NS     BPCL.NS  BRITANNIA.NS     CIPLA.NS  \
# 2023-07-11 09:15:00     887.549988  387.500000   5083.000000  1021.450012
# 2023-07-11 09:30:00     890.299988  386.899994   5151.000000  1028.650024
# 2023-07-11 09:45:00     890.150024  386.700012   5137.000000  1028.250000
# 2023-07-11 10:00:00     890.299988  385.850006   5117.049805  1026.650024
# 2023-07-11 10:15:00     889.099976  387.500000   5124.350098  1026.349976
#
#                      COALINDIA.NS  DIVISLAB.NS   DRREDDY.NS  EICHERMOT.NS  \
# 2023-07-11 09:15:00    234.149994  3675.949951  5152.000000   3206.300049
# 2023-07-11 09:30:00    234.500000  3673.550049  5188.049805   3211.899902
# 2023-07-11 09:45:00    234.100006  3672.000000  5204.399902   3217.350098
# 2023-07-11 10:00:00    234.100006  3658.899902  5197.500000   3220.500000
# 2023-07-11 10:15:00    235.199997  3648.050049  5194.200195   3223.050049
#
#                        GRASIM.NS   HCLTECH.NS      HDFC.NS  HDFCBANK.NS  \
# 2023-07-11 09:15:00  1753.849976  1127.000000  2769.149902  1659.099976
# 2023-07-11 09:30:00  1751.150024  1123.650024  2769.649902  1659.949951
# 2023-07-11 09:45:00  1755.900024  1121.900024  2770.100098  1660.300049
# 2023-07-11 10:00:00  1757.849976  1119.500000  2769.850098  1660.849976
# 2023-07-11 10:15:00  1759.150024  1117.150024  2770.050049  1661.900024
#
#                      HDFCLIFE.NS  HEROMOTOCO.NS  HINDALCO.NS  HINDUNILVR.NS  \
# 2023-07-11 09:15:00   682.049988    3095.850098   427.649994    2666.600098
# 2023-07-11 09:30:00   682.950012    3102.500000   428.399994    2682.800049
# 2023-07-11 09:45:00   683.099976    3096.100098   428.899994    2678.800049
# 2023-07-11 10:00:00   682.049988    3099.100098   428.649994    2683.550049
# 2023-07-11 10:15:00   682.950012    3100.000000   429.649994    2689.100098
#
#                      ICICIBANK.NS  INDUSINDBK.NS  INFY.NS      ITC.NS  \
# 2023-07-11 09:15:00    948.200012    1379.300049      NaN  468.000000
# 2023-07-11 09:30:00    950.650024    1380.000000      NaN  468.899994
# 2023-07-11 09:45:00    950.349976    1375.849976      NaN  468.250000
# 2023-07-11 10:00:00    950.400024    1378.150024      NaN  468.649994
# 2023-07-11 10:15:00    950.599976    1376.400024      NaN  469.299988
#
#                      JSWSTEEL.NS  KOTAKBANK.NS        LT.NS       M&M.NS  \
# 2023-07-11 09:15:00   810.650024   1878.000000  2467.000000  1565.800049
# 2023-07-11 09:30:00   807.400024   1884.099976  2468.250000  1567.000000
# 2023-07-11 09:45:00   807.799988   1884.800049  2475.899902  1567.000000
# 2023-07-11 10:00:00   806.700012   1891.250000  2470.699951  1567.099976
# 2023-07-11 10:15:00   808.200012   1891.750000  2476.750000  1565.300049
#
#                        MARUTI.NS  NESTLEIND.NS     NTPC.NS     ONGC.NS  \
# 2023-07-11 09:15:00  9820.049805  22675.000000  192.100006  163.399994
# 2023-07-11 09:30:00  9861.000000  22779.400391  191.300003  163.550003
# 2023-07-11 09:45:00  9871.900391  22868.750000  191.600006  164.199997
# 2023-07-11 10:00:00  9852.000000  22800.500000  191.550003  164.300003
# 2023-07-11 10:15:00  9880.400391  22760.050781  191.649994  164.550003
#
#                      POWERGRID.NS  RELIANCE.NS   SBILIFE.NS     SBIN.NS  \
# 2023-07-11 09:15:00    250.850006  2760.000000  1301.699951  592.200012
# 2023-07-11 09:30:00    251.550003  2754.000000  1301.000000  591.000000
# 2023-07-11 09:45:00    251.949997  2756.300049  1306.000000  590.200012
# 2023-07-11 10:00:00    252.449997  2751.899902  1307.099976  591.049988
# 2023-07-11 10:15:00    253.100006  2748.350098  1304.750000  591.799988
#
#                      SUNPHARMA.NS  TATACONSUM.NS  TATAMOTORS.NS  TATASTEEL.NS  \
# 2023-07-11 09:15:00   1055.400024     830.049988     623.200012    115.300003
# 2023-07-11 09:30:00   1061.599976     831.099976     623.950012    115.150002
# 2023-07-11 09:45:00   1065.199951     831.000000     624.500000    115.250000
# 2023-07-11 10:00:00   1063.000000     832.299988     624.000000    115.400002
# 2023-07-11 10:15:00   1066.199951     832.400024     624.049988    115.550003
#
#                           TCS.NS     TECHM.NS     TITAN.NS  ULTRACEMCO.NS  \
# 2023-07-11 09:15:00  3271.800049  1146.500000  3065.449951    8362.950195
# 2023-07-11 09:30:00  3276.000000  1149.449951  3063.500000    8360.700195
# 2023-07-11 09:45:00  3277.350098  1151.449951  3065.050049    8370.000000
# 2023-07-11 10:00:00  3280.449951  1152.349976  3064.250000    8375.900391
# 2023-07-11 10:15:00  3276.800049  1152.500000  3063.550049    8392.650391
#
#                          UPL.NS    WIPRO.NS
# 2023-07-11 09:15:00  644.950012  388.500000
# 2023-07-11 09:30:00  644.700012  389.350006
# 2023-07-11 09:45:00  646.950012  388.799988
# 2023-07-11 10:00:00  649.299988  389.200012
# 2023-07-11 10:15:00  648.700012  389.100006

# %%
new = pd.DataFrame()
for i in modified_list:
    new[i] = data[i].rolling(window=7).std() * np.sqrt(7)
new = new.tail(7)
row_index = -1
sorted_data = new.iloc[:, np.argsort(new.iloc[row_index])]
# row_index = 2
# sorted_data = data.iloc[:, np.argsort(np.sort(data.iloc[row_index]))] 
# sorted_data = new.sort_values(by=new.columns[2]) 
column_list = list(sorted_data.columns)
reversed_list = column_list[::-1]
print(column_list)
print(reversed_list)
# Out:
# ['NESTLEIND.NS', 'TATAMOTORS.NS', 'HDFCLIFE.NS', 'COALINDIA.NS', 'MARUTI.NS', 'HINDALCO.NS', 'BPCL.NS', 'ONGC.NS', 'RELIANCE.NS', 'ULTRACEMCO.NS', 'TCS.NS', 'ITC.NS', 'BAJAJ-AUTO.NS', 'TITAN.NS', 'ICICIBANK.NS', 'SBILIFE.NS', 'AXISBANK.NS', 'TATACONSUM.NS', 'LT.NS', 'ADANIPORTS.NS', 'BHARTIARTL.NS', 'TECHM.NS', 'SBIN.NS', 'INFY.NS', 'HINDUNILVR.NS', 'DIVISLAB.NS', 'HCLTECH.NS', 'WIPRO.NS', 'GRASIM.NS', 'BRITANNIA.NS', 'EICHERMOT.NS', 'CIPLA.NS', 'HEROMOTOCO.NS', 'ADANIENT.NS', 'INDUSINDBK.NS', 'BAJAJFINSV.NS', 'DRREDDY.NS', 'TATASTEEL.NS', 'HDFC.NS', 'JSWSTEEL.NS', 'ASIANPAINT.NS', 'HDFCBANK.NS', 'M&M.NS', 'KOTAKBANK.NS', 'POWERGRID.NS', 'UPL.NS', 'APOLLOHOSP.NS', 'BAJFINANCE.NS', 'SUNPHARMA.NS', 'NTPC.NS']
# ['NTPC.NS', 'SUNPHARMA.NS', 'BAJFINANCE.NS', 'APOLLOHOSP.NS', 'UPL.NS', 'POWERGRID.NS', 'KOTAKBANK.NS', 'M&M.NS', 'HDFCBANK.NS', 'ASIANPAINT.NS', 'JSWSTEEL.NS', 'HDFC.NS', 'TATASTEEL.NS', 'DRREDDY.NS', 'BAJAJFINSV.NS', 'INDUSINDBK.NS', 'ADANIENT.NS', 'HEROMOTOCO.NS', 'CIPLA.NS', 'EICHERMOT.NS', 'BRITANNIA.NS', 'GRASIM.NS', 'WIPRO.NS', 'HCLTECH.NS', 'DIVISLAB.NS', 'HINDUNILVR.NS', 'INFY.NS', 'SBIN.NS', 'TECHM.NS', 'BHARTIARTL.NS', 'ADANIPORTS.NS', 'LT.NS', 'TATACONSUM.NS', 'AXISBANK.NS', 'SBILIFE.NS', 'ICICIBANK.NS', 'TITAN.NS', 'BAJAJ-AUTO.NS', 'ITC.NS', 'TCS.NS', 'ULTRACEMCO.NS', 'RELIANCE.NS', 'ONGC.NS', 'BPCL.NS', 'HINDALCO.NS', 'MARUTI.NS', 'COALINDIA.NS', 'HDFCLIFE.NS', 'TATAMOTORS.NS', 'NESTLEIND.NS']

# %%
reader = pd.read_csv("high_volatile_stock_large_cap.csv")
# reader = pd.read_csv('Nifty_50_companies_list.csv')
# for j in reader['Symbol']:
balance = 100000
#     cp = str(j) + ".NS"
#     print(str(cp))

cp = 'ADANIPORTS.NS'

# print("Bajaj Finance")
print(cp)
df1 = yf.download(cp,Starttime,Endtime,interval=Interval)
df2 = yf.download(tickers=cp,period='1d',interval=Interval)
data = pd.concat([df1, df2])
data.index = pd.to_datetime(data.index)
print(data.tail())
target_time = datetime.time(17, 15)

# assume dataframe named data is already defined

# calculate volatility and add new column to data
data['Volatility'] = data['Close'].rolling(window=7).std() * np.sqrt(7)
print(data['Volatility'].head())
# calculate EMA of 8 and 5 and add new columns to data
data['EMA_8'] = data['Close'].ewm(span=8).mean()
data['EMA_5'] = data['Close'].ewm(span=5).mean()
# print(data)
# loop through index of data and check for EMA8 crossing EMA5
print("step 1 done")
# print(data.loc[data.index[1]]['EMA_8'])
pur = 0
quantity =0
quantity1 = 0
for i in data.index:
    tmp = i
    # print(tmp.time())
    # print(i)
    # print(data[i]['EMA8'])
    if(str(i.time()) == "09:15:00"):
        pass
    else:
        # if(i == data.index[-1]):
        #     time_to_add = datetime.timedelta(minutes=15, seconds=5)  # Adjust this to the desired duration

        #     target_time = (datetime.datetime.combine(datetime.date.today(), target_time) + time_to_add).time()

        #     current_time = datetime.datetime.now()
        #     current_time = current_time.time()

        #     target_datetime = datetime.datetime.combine(datetime.date.today(), target_time)
        #     current_datetime = datetime.datetime.combine(datetime.date.today(), current_time)

        #     time_difference = target_datetime - current_datetime
        #     time_difference_seconds = time_difference.total_seconds()
        #     time.sleep(time_difference_seconds)
        #     df1 = yf.download(cp,Starttime,Endtime,interval=Interval)
        #     df2 = yf.download(tickers=cp,period='1d',interval=Interval)
        #     data = pd.concat([df1, df2])
        #     data.index = pd.to_datetime(data.index)
        #     data['Volatility'] = data['Close'].rolling(window=7).std() * np.sqrt(7)
        #     # print(data['Volatility'])
        #     # calculate EMA of 8 and 5 and add new columns to data
        #     data['EMA_8'] = data['Close'].ewm(span=8).mean()
        #     data['EMA_5'] = data['Close'].ewm(span=5).mean()
        #     print(data.tail())
        
        if(data.loc[i]['EMA_8'] < data.loc[i]['EMA_5'] and data.loc[i - timedelta(minutes=15)]['EMA_8'] > data.loc[i - timedelta(minutes=15)]['EMA_5'] and pur == 0 and data.loc[i]['Volatility'] > 5):
            print("before purchase at time " + str(i) + " balance1 = " + str(balance))
            quantity = balance/data.loc[i]['Open']
            balance = balance - quantity*data.loc[i]['Open']
            print("quantity = " + str(quantity))
            print("after purchase at time " + str(i) + " balance1 = " + str(balance))
            pur = 1

        # elif(data.loc[i]['EMA_8'] < data.loc[i]['EMA_5'] and data.loc[i + timedelta(minutes=Interval)]['EMA_8'] > data.loc[i + timedelta(minutes=Interval)]['EMA_5'] and pur == 0 and data.loc[i]['Volatility'] > 0):
        #     print("before purchase at time " + str(i) + " balance2 = " + str(balance))
        #     quantity = balance/data.loc[i]['Open']
        #     balance = balance + quantity*data.loc[i]['Open']
        #     print("quantity = " + str(quantity))
        #     print("after purchase at time " + str(i) + " balance2 = " + str(balance))
        #     pur = 1
        # elif(data.loc[i]['EMA_8'] > data.loc[i]['EMA_5'] and data.loc[i + timedelta(minutes=Interval)]['EMA_8'] > data.loc[i + timedelta(minutes=Interval)]['EMA_5'] and pur == 0 and data.loc[i]['Volatility'] > 20):
        #     quantity1 = balance/data.loc[i]['Open']
        #     balance = balance + quantity*data.loc[i]['Open']
        #     print("after purchase at time "+ str(i) + "balance2 = " + str(balance))
        #     pur = 1
        elif(str(tmp.time()) == "15:30:00" and pur == 1):
            print("before sell at time " + str(i) + " balance1 = " + str(balance))
            balance = balance + quantity*data.loc[i]['Close']
            print("quantity = " + str(quantity))
            print("after sell at time " + str(i) + " balance1 = " + str(balance))
            quantity = 0
            pur = 0
            print('day over                 ')
            print('                 ')
            print('                 ')
            print('                 ')
    



        elif(data.loc[i]['EMA_8'] > data.loc[i]['EMA_5'] and data.loc[i - timedelta(minutes=15)]['EMA_8'] < data.loc[i - timedelta(minutes=15)]['EMA_5'] and pur == 1):
            print("before sell at time " + str(i) + " balance1 = " + str(balance))
            balance = balance + quantity*data.loc[i]['Close']
            print("quantity = " + str(quantity))
            print("after sell at time " + str(i) + " balance1 = " + str(balance))
            quantity = 0
            pur = 0
        # elif(str(tmp.time()) == "15:15:00"):
        #     print('day over                 ')
        #     print('                 ')
        #     print('                 ')
        #     print('                 ')
            

        
            

        # elif(data.loc[i]['EMA_8'] > data.loc[i]['EMA_5'] and data.loc[i + timedelta(minutes=Interval)]['EMA_8'] < data.loc[i + timedelta(minutes=Interval)]['EMA_5'] and pur == 1):
        #     print("before sell at time " + str(i) + " balance2 = " + str(balance))
        #     balance = balance - quantity*data.loc[i]['Close']
        #     print("quantity = " + str(quantity))
        #     print("after sell at time " + str(i) + " balance2 = " + str(balance))
        #     quantity = 0
        #     pur = 0
        # elif(data.loc[i]['EMA_8'] > data.loc[i]['EMA_5'] and data.loc[i + timedelta(minutes=Interval)]['EMA_8'] > data.loc[i + timedelta(minutes=Interval)]['EMA_5'] and pur == 1):
        #     balance = balance - quantity1*data.loc[i]['Close']
        #     print("after sell 2 = " + str(balance))
        #     pur = 0
        elif(str(i.time()) == "15:30:00"):
            print('day over                 ' + str(i.date()))
            print('                 ')
            print('                 ')
            print('                 ')
            

if(pur == 1):
    if(quantity1>0):
        balance = balance - quantity1*data.loc[i]['Close']
    elif(quantity>0):
        balance = balance + quantity*data.loc[i]['Close']
print(balance)
# Out:
# ADANIPORTS.NS
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[4], line 15
#      13 # print("Bajaj Finance")
#      14 print(cp)
# ---> 15 df1 = yf.download(cp,Starttime,Endtime,interval=Interval)
#      16 df2 = yf.download(tickers=cp,period='1d',interval=Interval)
#      17 data = pd.concat([df1, df2])
#
# File c:\Users\MihirVangani\anaconda3\envs\myenv\Lib\site-packages\yfinance\multi.py:131, in download(tickers, start, end, actions, threads, ignore_tz, group_by, auto_adjust, back_adjust, repair, keepna, progress, period, show_errors, interval, prepost, proxy, rounding, timeout)
#     124         _download_one_threaded(ticker, period=period, interval=interval,
#     125                                start=start, end=end, prepost=prepost,
#     126                                actions=actions, auto_adjust=auto_adjust,
#     127                                back_adjust=back_adjust, repair=repair, keepna=keepna,
#     128                                progress=(progress and i > 0), proxy=proxy,
#     129                                rounding=rounding, timeout=timeout)
#     130     while len(shared._DFS) < len(tickers):
# --> 131         _time.sleep(0.01)
#     133 # download synchronously
#     134 else:
#     135     for i, ticker in enumerate(tickers):
#
# KeyboardInterrupt:

# %%
import pandas as pd
import ta
import datetime
reader = pd.read_csv("Nifty_50_companies_list.csv")
# reader = pd.read_csv('Nifty_50_companies_list.csv')
for j in reversed_list:
    balance = 100000
    # cp = str(j) + ".NS"
    cp = j
    print(str(cp))
    # print("Bajaj Finance")
    df1 = yf.download(cp,Starttime,Endtime,interval=Interval)
    data = df1
    # df2 = yf.download(tickers='BAJFINANCE.NS',period='1d',interval=Interval)
    # data = pd.concat([df1, df2])
    data.index = pd.to_datetime(data.index)
    print(data.tail())
    target_time = datetime.time(13, 00)

    # assume dataframe named data is already defined

    # calculate volatility and add new column to data
    data['Volatility'] = data['Close'].rolling(window=7).std() * np.sqrt(7)
    # print(data['Volatility'])
    # calculate EMA of 8 and 5 and add new columns to data
    data['EMA_8'] = data['Close'].ewm(span=8).mean()
    data['EMA_5'] = data['Close'].ewm(span=5).mean()
    # print(data)
    # loop through index of data and check for EMA8 crossing EMA5
    print("step 1 done")
    # print(data.loc[data.index[1]]['EMA_8'])
    pur = 0
    quantity =0
    quantity1 = 0
    for i in data.index:
        tmp = i
        # print(tmp.time())
        # print(i)
        # print(data[i]['EMA8'])
        if(str(i.time()) == "09:15:00" or cp == "AURIONPRO.NS"):
            pass
        else:
            # if(i == data.index[-2]):
            #     time_to_add = datetime.timedelta(minutes=15, seconds=5)  # Adjust this to the desired duration

            #     target_time = (datetime.datetime.combine(datetime.date.today(), target_time) + time_to_add).time()

            #     current_time = datetime.datetime.now()
            #     current_time = current_time.time()

            #     target_datetime = datetime.datetime.combine(datetime.date.today(), target_time)
            #     current_datetime = datetime.datetime.combine(datetime.date.today(), current_time)

            #     time_difference = target_datetime - current_datetime
            #     time_difference_seconds = time_difference.total_seconds()
            #     time.sleep(time_difference_seconds)
            #     df1 = yf.download('BAJFINANCE.NS',Starttime,Endtime,interval=Interval)
            #     df2 = yf.download(tickers='BAJFINANCE.NS',period='1d',interval=Interval)
            #     data = pd.concat([df1, df2])
            #     data.index = pd.to_datetime(data.index)
            #     data['Volatility'] = data['Close'].rolling(window=7).std() * np.sqrt(7)
            #     # print(data['Volatility'])
            #     # calculate EMA of 8 and 5 and add new columns to data
            #     data['EMA_8'] = data['Close'].ewm(span=8).mean()
            #     data['EMA_5'] = data['Close'].ewm(span=5).mean()
            #     print(data.tail())
            
            if(data.loc[i]['EMA_8'] < data.loc[i]['EMA_5'] and data.loc[i - timedelta(minutes=15)]['EMA_8'] > data.loc[i - timedelta(minutes=15)]['EMA_5'] and pur == 0 and data.loc[i]['Volatility'] > 10):
                print("before purchase at time " + str(i) + " balance1 = " + str(balance))
                quantity = balance/data.loc[i]['Open']
                balance = balance - quantity*data.loc[i]['Open'] - 40
                print("quantity = " + str(quantity))
                print("after purchase at time " + str(i) + " balance1 = " + str(balance))
                pur = 1

            # elif(data.loc[i]['EMA_8'] < data.loc[i]['EMA_5'] and data.loc[i + timedelta(minutes=Interval)]['EMA_8'] > data.loc[i + timedelta(minutes=Interval)]['EMA_5'] and pur == 0 and data.loc[i]['Volatility'] > 0):
            #     print("before purchase at time " + str(i) + " balance2 = " + str(balance))
            #     quantity = balance/data.loc[i]['Open']
            #     balance = balance + quantity*data.loc[i]['Open']
            #     print("quantity = " + str(quantity))
            #     print("after purchase at time " + str(i) + " balance2 = " + str(balance))
            #     pur = 1
            # elif(data.loc[i]['EMA_8'] > data.loc[i]['EMA_5'] and data.loc[i + timedelta(minutes=Interval)]['EMA_8'] > data.loc[i + timedelta(minutes=Interval)]['EMA_5'] and pur == 0 and data.loc[i]['Volatility'] > 20):
            #     quantity1 = balance/data.loc[i]['Open']
            #     balance = balance + quantity*data.loc[i]['Open']
            #     print("after purchase at time "+ str(i) + "balance2 = " + str(balance))
            #     pur = 1
            elif(str(tmp.time()) == "15:15:00" and pur == 1):
                print("before sell at time " + str(i) + " balance1 = " + str(balance))
                balance = balance + quantity*data.loc[i]['Close'] - 40
                print("quantity = " + str(quantity))
                print("after sell at time " + str(i) + " balance1 = " + str(balance))
                quantity = 0
                pur = 0
                print('day over                 ')
                # print('                 ')
                # print('                 ')
                # print('                 ')
        



            elif(data.loc[i]['EMA_8'] > data.loc[i]['EMA_5'] and data.loc[i - timedelta(minutes=15)]['EMA_8'] < data.loc[i - timedelta(minutes=15)]['EMA_5'] and pur == 1):
                print("before sell at time " + str(i) + " balance1 = " + str(balance))
                balance = balance + quantity*data.loc[i]['Close'] - 40
                print("quantity = " + str(quantity))
                print("after sell at time " + str(i) + " balance1 = " + str(balance))
                quantity = 0
                pur = 0
            elif(str(tmp.time()) == "15:15:00"):
                print('day over                 ')
                # print('                 ')
                # print('                 ')
                # print('                 ')
                

            
                

            # elif(data.loc[i]['EMA_8'] > data.loc[i]['EMA_5'] and data.loc[i + timedelta(minutes=Interval)]['EMA_8'] < data.loc[i + timedelta(minutes=Interval)]['EMA_5'] and pur == 1):
            #     print("before sell at time " + str(i) + " balance2 = " + str(balance))
            #     balance = balance - quantity*data.loc[i]['Close']
            #     print("quantity = " + str(quantity))
            #     print("after sell at time " + str(i) + " balance2 = " + str(balance))
            #     quantity = 0
            #     pur = 0
            # elif(data.loc[i]['EMA_8'] > data.loc[i]['EMA_5'] and data.loc[i + timedelta(minutes=Interval)]['EMA_8'] > data.loc[i + timedelta(minutes=Interval)]['EMA_5'] and pur == 1):
            #     balance = balance - quantity1*data.loc[i]['Close']
            #     print("after sell 2 = " + str(balance))
            #     pur = 0
    if(pur == 1):
        if(quantity1>0):
            balance = balance - quantity1*data.loc[i]['Close'] - 40
        elif(quantity>0):
            balance = balance + quantity*data.loc[i]['Close'] - 40
    print(balance)
# Out:
# NTPC.NS
# [*********************100%***********************]  1 of 1 completed
#                            Open        High         Low       Close  \
# Datetime
# 2023-07-10 14:15:00  191.050003  191.699997  191.050003  191.500000
# 2023-07-10 14:30:00  191.550003  191.550003  191.199997  191.449997
# 2023-07-10 14:45:00  191.449997  191.949997  191.399994  191.750000
# 2023-07-10 15:00:00  191.850006  191.949997  191.300003  191.600006
# 2023-07-10 15:15:00  191.600006  191.699997  191.399994  191.550003
#
#                       Adj Close   Volume
# Datetime
# 2023-07-10 14:15:00  191.500000   271758
# 2023-07-10 14:30:00  191.449997   574433
# 2023-07-10 14:45:00  191.750000   271014
# 2023-07-10 15:00:00  191.600006   694973
# 2023-07-10 15:15:00  191.550003  1236128
# step 1 done
# day over
# day over
# day over
# day over
# day over
# day over
# day over
# day over
# day over
# day over
# day over
# day over
# day over
# day over
# day over
# day over
# day over
# day over
# day over
# 100000
# SUNPHARMA.NS
# [*********************100%***********************]  1 of 1 completed
#                             Open         High          Low        Close  \
# Datetime
# 2023-07-10 14:15:00  1045.550049  1046.000000  1043.800049  1045.000000
# 2023-07-10 14:30:00  1045.000000  1046.099976  1043.250000  1043.849976
# 2023-07-10 14:45:00  1044.150024  1045.199951  1042.750000  1043.000000
# 2023-07-10 15:00:00  1043.000000  1043.699951  1038.000000  1043.699951
# 2023-07-10 15:15:00  1043.650024  1050.550049  1043.500000  1045.000000
#
#                        Adj Close  Volume
# Datetime
# 2023-07-10 14:15:00  1045.000000   14350
# 2023-07-10 14:30:00  1043.849976   19972
# 2023-07-10 14:45:00  1043.000000   38374
# 2023-07-10 15:00:00  1043.699951  170638
# 2023-07-10 15:15:00  1045.000000  204383
# step 1 done
# day over
# day over
# day over
# day over
# day over
# day over
# day over
# day over
# day over
# day over
# day over
# day over
# day over
# day over
# day over
# day over
# day over
# day over
# day over
# 100000
# BAJFINANCE.NS
# [*********************100%***********************]  1 of 1 completed
#                             Open         High          Low        Close  \
# Datetime
# 2023-07-10 14:15:00  7504.950195  7530.549805  7496.100098  7530.049805
# 2023-07-10 14:30:00  7530.000000  7594.250000  7523.750000  7556.850098
# 2023-07-10 14:45:00  7556.850098  7556.899902  7531.000000  7541.100098
# 2023-07-10 15:00:00  7538.149902  7542.149902  7520.049805  7520.049805
# 2023-07-10 15:15:00  7521.950195  7561.149902  7518.049805  7533.250000
#
#                        Adj Close  Volume
# Datetime
# 2023-07-10 14:15:00  7530.049805   56069
# 2023-07-10 14:30:00  7556.850098   82244
# 2023-07-10 14:45:00  7541.100098   23590
# 2023-07-10 15:00:00  7520.049805   58154
# 2023-07-10 15:15:00  7533.250000   52784
# step 1 done
# before purchase at time 2023-06-12 11:45:00 balance1 = 100000
# quantity = 14.111636967114304
# after purchase at time 2023-06-12 11:45:00 balance1 = -40.0
# before sell at time 2023-06-12 13:45:00 balance1 = -40.0
# quantity = 14.111636967114304
# after sell at time 2023-06-12 13:45:00 balance1 = 99958.09728554256
# day over
# day over
# before purchase at time 2023-06-14 13:45:00 balance1 = 99958.09728554256
# quantity = 14.070381208111206
# after purchase at time 2023-06-14 13:45:00 balance1 = -40.0
# before sell at time 2023-06-14 14:30:00 balance1 = -40.0
# quantity = 14.070381208111206
# after sell at time 2023-06-14 14:30:00 balance1 = 99733.17510722035
# day over
# before purchase at time 2023-06-15 10:15:00 balance1 = 99733.17510722035
# quantity = 14.053557168472173
# after purchase at time 2023-06-15 10:15:00 balance1 = -40.0
# before sell at time 2023-06-15 11:30:00 balance1 = -40.0
# quantity = 14.053557168472173
# after sell at time 2023-06-15 11:30:00 balance1 = 99511.93960251259
# before purchase at time 2023-06-15 12:30:00 balance1 = 99511.93960251259
# quantity = 14.028114833834374
# after purchase at time 2023-06-15 12:30:00 balance1 = -40.0
# before sell at time 2023-06-15 15:15:00 balance1 = -40.0
# quantity = 14.028114833834374
# after sell at time 2023-06-15 15:15:00 balance1 = 99912.40253557143
# day over
# before purchase at time 2023-06-16 14:15:00 balance1 = 99912.40253557143
# quantity = 13.934784175114565
# after purchase at time 2023-06-16 14:15:00 balance1 = -40.0
# before sell at time 2023-06-16 15:15:00 balance1 = -40.0
# quantity = 13.934784175114565
# after sell at time 2023-06-16 15:15:00 balance1 = 100180.7721399493
# day over
# day over
# before purchase at time 2023-06-20 13:30:00 balance1 = 100180.7721399493
# quantity = 13.844102453306732
# after purchase at time 2023-06-20 13:30:00 balance1 = -40.0
# before sell at time 2023-06-20 13:45:00 balance1 = -40.0
# quantity = 13.844102453306732
# after sell at time 2023-06-20 13:45:00 balance1 = 99915.95202023453
# before purchase at time 2023-06-20 14:00:00 balance1 = 99915.95202023453
# quantity = 13.833026723000765
# after purchase at time 2023-06-20 14:00:00 balance1 = -40.0
# before sell at time 2023-06-20 15:15:00 balance1 = -40.0
# quantity = 13.833026723000765
# after sell at time 2023-06-20 15:15:00 balance1 = 100223.27676847855
# day over
# before purchase at time 2023-06-21 14:00:00 balance1 = 100223.27676847855
# quantity = 13.896063753345452
# after purchase at time 2023-06-21 14:00:00 balance1 = -40.0
# before sell at time 2023-06-21 14:30:00 balance1 = -40.0
# quantity = 13.896063753345452
# after sell at time 2023-06-21 14:30:00 balance1 = 100048.77946384337
# day over
# day over
# before purchase at time 2023-06-23 12:30:00 balance1 = 100048.77946384337
# quantity = 14.302387972387459
# after purchase at time 2023-06-23 12:30:00 balance1 = -40.0
# before sell at time 2023-06-23 14:15:00 balance1 = -40.0
# quantity = 14.302387972387459
# after sell at time 2023-06-23 14:15:00 balance1 = 100165.4372984637
# day over
# before purchase at time 2023-06-26 09:30:00 balance1 = 100165.4372984637
# quantity = 14.277325785014112
# after purchase at time 2023-06-26 09:30:00 balance1 = -40.0
# before sell at time 2023-06-26 09:45:00 balance1 = -40.0
# quantity = 14.277325785014112
# after sell at time 2023-06-26 09:45:00 balance1 = 99824.15805378764
# before purchase at time 2023-06-26 11:30:00 balance1 = 99824.15805378764
# quantity = 14.26049254491612
# after purchase at time 2023-06-26 11:30:00 balance1 = -40.0
# before sell at time 2023-06-26 12:00:00 balance1 = -40.0
# quantity = 14.26049254491612
# after sell at time 2023-06-26 12:00:00 balance1 = 99379.80525451749
# before purchase at time 2023-06-26 14:30:00 balance1 = 99379.80525451749
# quantity = 14.23983453997958
# after purchase at time 2023-06-26 14:30:00 balance1 = -40.0
# before sell at time 2023-06-26 15:15:00 balance1 = -40.0
# quantity = 14.23983453997958
# after sell at time 2023-06-26 15:15:00 balance1 = 99580.33277617277
# day over
# before purchase at time 2023-06-27 12:45:00 balance1 = 99580.33277617277
# quantity = 14.278797358212326
# after purchase at time 2023-06-27 12:45:00 balance1 = -40.0
# before sell at time 2023-06-27 15:15:00 balance1 = -40.0
# quantity = 14.278797358212326
# after sell at time 2023-06-27 15:15:00 balance1 = 100146.44835663187
# day over
# Unexpected exception formatting exception. Falling back to standard exception
# Traceback (most recent call last):
#   File "pandas\_libs\index.pyx", line 548, in pandas._libs.index.DatetimeEngine.get_loc
#   File "pandas\_libs\hashtable_class_helper.pxi", line 2263, in pandas._libs.hashtable.Int64HashTable.get_item
#   File "pandas\_libs\hashtable_class_helper.pxi", line 2273, in pandas._libs.hashtable.Int64HashTable.get_item
# KeyError: 1687964400000000000
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "c:\Users\MihirVangani\anaconda3\envs\myenv\Lib\site-packages\pandas\core\indexes\base.py", line 3802, in get_loc
#     return self._engine.get_loc(casted_key)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "pandas\_libs\index.pyx", line 516, in pandas._libs.index.DatetimeEngine.get_loc
#   File "pandas\_libs\index.pyx", line 550, in pandas._libs.index.DatetimeEngine.get_loc
# KeyError: Timestamp('2023-06-28 15:00:00')
#
# The above exception was the direct cause of the following exception:
#
# Traceback (most recent call last):
#   File "c:\Users\MihirVangani\anaconda3\envs\myenv\Lib\site-packages\pandas\core\indexes\datetimes.py", line 736, in get_loc
#     return Index.get_loc(self, key, method, tolerance)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "c:\Users\MihirVangani\anaconda3\envs\myenv\Lib\site-packages\pandas\core\indexes\base.py", line 3804, in get_loc
#     raise KeyError(key) from err
# KeyError: Timestamp('2023-06-28 15:00:00')
#
# The above exception was the direct cause of the following exception:
#
# Traceback (most recent call last):
#   File "c:\Users\MihirVangani\anaconda3\envs\myenv\Lib\site-packages\IPython\core\interactiveshell.py", line 3460, in run_code
#     exec(code_obj, self.user_global_ns, self.user_ns)
#   File "C:\Users\MihirVangani\AppData\Local\Temp\ipykernel_30340\1902980638.py", line 68, in <module>
#     if(data.loc[i]['EMA_8'] < data.loc[i]['EMA_5'] and data.loc[i - timedelta(minutes=15)]['EMA_8'] > data.loc[i - timedelta(minutes=15)]['EMA_5'] and pur == 0 and data.loc[i]['Volatility'] > 10):
#                                                        ~~~~~~~~^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "c:\Users\MihirVangani\anaconda3\envs\myenv\Lib\site-packages\pandas\core\indexing.py", line 1073, in __getitem__
#     return self._getitem_axis(maybe_callable, axis=axis)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "c:\Users\MihirVangani\anaconda3\envs\myenv\Lib\site-packages\pandas\core\indexing.py", line 1312, in _getitem_axis
#     return self._get_label(key, axis=axis)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "c:\Users\MihirVangani\anaconda3\envs\myenv\Lib\site-packages\pandas\core\indexing.py", line 1260, in _get_label
#     return self.obj.xs(label, axis=axis)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "c:\Users\MihirVangani\anaconda3\envs\myenv\Lib\site-packages\pandas\core\generic.py", line 4056, in xs
#     loc = index.get_loc(key)
#           ^^^^^^^^^^^^^^^^^^
#   File "c:\Users\MihirVangani\anaconda3\envs\myenv\Lib\site-packages\pandas\core\indexes\datetimes.py", line 738, in get_loc
#     raise KeyError(orig_key) from err
# KeyError: Timestamp('2023-06-28 15:00:00')
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "c:\Users\MihirVangani\anaconda3\envs\myenv\Lib\site-packages\IPython\core\interactiveshell.py", line 2057, in showtraceback
#     stb = self.InteractiveTB.structured_traceback(
#           ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "c:\Users\MihirVangani\anaconda3\envs\myenv\Lib\site-packages\IPython\core\ultratb.py", line 1288, in structured_traceback
#     return FormattedTB.structured_traceback(
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "c:\Users\MihirVangani\anaconda3\envs\myenv\Lib\site-packages\IPython\core\ultratb.py", line 1177, in structured_traceback
#     return VerboseTB.structured_traceback(
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "c:\Users\MihirVangani\anaconda3\envs\myenv\Lib\site-packages\IPython\core\ultratb.py", line 1049, in structured_traceback
#     formatted_exceptions += self.format_exception_as_a_whole(etype, evalue, etb, lines_of_context,
#                             ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "c:\Users\MihirVangani\anaconda3\envs\myenv\Lib\site-packages\IPython\core\ultratb.py", line 935, in format_exception_as_a_whole
#     self.get_records(etb, number_of_lines_of_context, tb_offset) if etb else []
#     ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "c:\Users\MihirVangani\anaconda3\envs\myenv\Lib\site-packages\IPython\core\ultratb.py", line 1003, in get_records
#     lines, first = inspect.getsourcelines(etb.tb_frame)
#                    ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "c:\Users\MihirVangani\anaconda3\envs\myenv\Lib\inspect.py", line 1244, in getsourcelines
#     lines, lnum = findsource(object)
#                   ^^^^^^^^^^^^^^^^^^
#   File "c:\Users\MihirVangani\anaconda3\envs\myenv\Lib\inspect.py", line 1081, in findsource
#     raise OSError('could not get source code')
# OSError: could not get source code
